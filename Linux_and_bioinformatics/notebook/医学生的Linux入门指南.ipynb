# %% [markdown]
# # 1.1 进入目录

# %%
# 使用绝对路径
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
# 使用pwd来查看当前目录
# !pwd
# Out:
# /content/sample_data

# %%
# 后退到父目录
# %cd ..
# Out:
# /content

# %%
# 使用相对路径
# %cd ./sample_data

# %%
# 使用相对路径(./可以省略)
# %cd sample_data
# Out:
# /content/sample_data

# %%
# 回到主目录
# %cd
# Out:
# /root

# %% [markdown]
# # 1.2 查看目录下有哪些文件（文件夹）

# %%
# %cd /content/sample_data
# !ls
# Out:
# /content/sample_data
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# 列出详细信息
# !ls -l
# Out:
# total 55504
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 Apr 28 13:35 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 Apr 28 13:35 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 Apr 28 13:35 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Apr 28 13:35 mnist_train_small.csv
# -rwxr-xr-x 1 root root      962 Jan  1  2000 README.md

# %%
# 查看隐藏文件
# !touch .hide
# !ls -a
# Out:
# .	       california_housing_test.csv   mnist_test.csv
# ..	       california_housing_train.csv  mnist_train_small.csv
# anscombe.json  .hide			     README.md

# %%
# 参数的组合
# !ls -alh
# Out:
# total 55M
# drwxr-xr-x 1 root root 4.0K Apr 30 13:46 .
# drwxr-xr-x 1 root root 4.0K Apr 28 13:35 ..
# -rwxr-xr-x 1 root root 1.7K Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root 295K Apr 28 13:35 california_housing_test.csv
# -rw-r--r-- 1 root root 1.7M Apr 28 13:35 california_housing_train.csv
# -rw-r--r-- 1 root root    0 Apr 30 13:46 .hide
# -rw-r--r-- 1 root root  18M Apr 28 13:35 mnist_test.csv
# -rw-r--r-- 1 root root  35M Apr 28 13:35 mnist_train_small.csv
# -rwxr-xr-x 1 root root  962 Jan  1  2000 README.md

# %% [markdown]
# # 1.3 创建文件（文件夹）

# %%
# 创建文件夹
# !mkdir newdir

# %%
# 创建文件
# !touch newtext

# %% [markdown]
# # 1.4 文件（文件夹）的操作

# %%
# 复制文件
# 极简语法：cp 旧文件 新文件
# !cp newtext newdir/newtext2

# %%
# 复制文件夹
# 极简语法：cp -R 旧文件夹 新文件夹
# !cp -R newdir ../

# %%
# 删除文件
# 极简语法：rm 旧文件 新文件
# !rm newtext

# %%
# 删除文件夹
# 极简语法：rm -R 旧文件夹 新文件夹
# !rm -R newdir/

# %%
# 移动（重命名）文件
# 极简语法：mv 旧文件 新文件
# !mv new2 new3

# %%
# 移动（重命名）文件夹
# 极简语法：mv 旧文件夹 新文件夹
# !mv ../newdir newdir2

# %% [markdown]
# # 1.5 查看文件内容

# %%
# 查看全部内容
# !cat california_housing_test.csv

# %%
# 查看前n行
# !head -5 california_housing_test.csv
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -122.050000,37.370000,27.000000,3885.000000,661.000000,1537.000000,606.000000,6.608500,344700.000000
# -118.300000,34.260000,43.000000,1510.000000,310.000000,809.000000,277.000000,3.599000,176500.000000
# -117.810000,33.780000,27.000000,3589.000000,507.000000,1484.000000,495.000000,5.793400,270500.000000
# -118.360000,33.820000,28.000000,67.000000,15.000000,49.000000,11.000000,6.135900,330000.000000

# %%
# 查看最后n行
# !tail -10 california_housing_test.csv
# Out:
# -118.230000,34.090000,49.000000,1638.000000,456.000000,1500.000000,430.000000,2.692300,150000.000000
# -117.170000,34.280000,13.000000,4867.000000,718.000000,780.000000,250.000000,7.199700,253800.000000
# -122.330000,37.390000,52.000000,573.000000,102.000000,232.000000,92.000000,6.226300,500001.000000
# -117.910000,33.600000,37.000000,2088.000000,510.000000,673.000000,390.000000,5.104800,500001.000000
# -117.930000,33.860000,35.000000,931.000000,181.000000,516.000000,174.000000,5.586700,182500.000000
# -119.860000,34.420000,23.000000,1450.000000,642.000000,1258.000000,607.000000,1.179000,225000.000000
# -118.140000,34.060000,27.000000,5257.000000,1082.000000,3496.000000,1036.000000,3.390600,237200.000000
# -119.700000,36.300000,10.000000,956.000000,201.000000,693.000000,220.000000,2.289500,62000.000000
# -117.120000,34.100000,40.000000,96.000000,14.000000,46.000000,14.000000,3.270800,162500.000000
# ...

# %%
# 搜索包含指定字串的行
# !grep 117.93 california_housing_test.csv
# Out:
# -117.930000,33.910000,24.000000,1698.000000,297.000000,676.000000,273.000000,5.201700,364600.000000
# -117.930000,34.060000,35.000000,1022.000000,183.000000,628.000000,187.000000,3.937500,187500.000000
# -117.930000,33.730000,27.000000,3662.000000,834.000000,3009.000000,743.000000,3.981600,179500.000000
# -117.930000,33.930000,25.000000,2431.000000,534.000000,1702.000000,523.000000,3.793300,184400.000000
# -117.930000,33.710000,10.000000,2775.000000,717.000000,1581.000000,633.000000,4.136600,158800.000000
# -117.930000,33.780000,28.000000,4380.000000,820.000000,2187.000000,835.000000,3.901800,182300.000000
# -117.930000,33.920000,34.000000,2271.000000,437.000000,1393.000000,433.000000,4.244300,174400.000000
# -117.930000,33.680000,33.000000,2664.000000,432.000000,1197.000000,429.000000,5.069000,264200.000000
# -117.930000,33.830000,30.000000,1561.000000,381.000000,1104.000000,391.000000,3.375000,201900.000000
# ...

# %% [markdown]
# # 2.1 下载

# %%
# !wget https://storage.googleapis.com/gatk-best-practices/somatic-hg38/af-only-gnomad.hg38.vcf.gz.tbi
# Out:
# --2025-04-30 14:02:55--  https://storage.googleapis.com/gatk-best-practices/somatic-hg38/af-only-gnomad.hg38.vcf.gz.tbi
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.174.207, 74.125.23.207, 74.125.203.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.174.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2443190 (2.3M) [application/octet-stream]
# Saving to: ‘af-only-gnomad.hg38.vcf.gz.tbi’
#
# af-only-gnomad.hg38 100%[===================>]   2.33M  2.60MB/s    in 0.9s
#
# 2025-04-30 14:02:56 (2.60 MB/s) - ‘af-only-gnomad.hg38.vcf.gz.tbi’ saved [2443190/2443190]

# %% [markdown]
# # 2.2 压缩与归档

# %%
# 压缩文件
# !gzip california_housing_train.csv

# %%
# 查看压缩文件的内容
# !zcat california_housing_train.csv.gz

# %%
# 解压
# !gunzip california_housing_train.csv.gz

# %%
# 归档
# !tar -zcvf new.tar.gz newdir2/
# Out:
# newdir2/

# %%
# 列出归档内容
# !tar -ztvf new.tar.gz
# Out:
# drwxr-xr-x root/root         0 2025-04-30 13:55 newdir2/

# %%
# 提取归档内容(用的最多)
# !tar -zxvf new.tar.gz
# Out:
# newdir2/

# %% [markdown]
# # 2.3 变量与环境变量

# %% [markdown]
# # 2.4 输出重定向

# %%
# !head -20 california_housing_test.csv > result

# %%
# !head -20 california_housing_test.csv

# %%
# !cat result

# %% [markdown]
# # 2.5 管道

# %%
# !cat california_housing_test.csv | head -5
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -122.050000,37.370000,27.000000,3885.000000,661.000000,1537.000000,606.000000,6.608500,344700.000000
# -118.300000,34.260000,43.000000,1510.000000,310.000000,809.000000,277.000000,3.599000,176500.000000
# -117.810000,33.780000,27.000000,3589.000000,507.000000,1484.000000,495.000000,5.793400,270500.000000
# -118.360000,33.820000,28.000000,67.000000,15.000000,49.000000,11.000000,6.135900,330000.000000

# %%
# !cat california_housing_test.csv > tmp

# %%
! head -5 tmp
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -122.050000,37.370000,27.000000,3885.000000,661.000000,1537.000000,606.000000,6.608500,344700.000000
# -118.300000,34.260000,43.000000,1510.000000,310.000000,809.000000,277.000000,3.599000,176500.000000
# -117.810000,33.780000,27.000000,3589.000000,507.000000,1484.000000,495.000000,5.793400,270500.000000
# -118.360000,33.820000,28.000000,67.000000,15.000000,49.000000,11.000000,6.135900,330000.000000

# %% [markdown]
# # 3.1 查看手册

# %%
# man XXX
# XXX --help
# XXX -h
# XXX
# !head -h
# Out:
# head: invalid option -- 'h'
# Try 'head --help' for more information.

# %% [markdown]
# # 3.2 循环

# %%
# !ls -lh > file_list
# !cat file_list
# Out:
# total 57M
# -rw-r--r-- 1 root root 2.4M Aug 23  2017 af-only-gnomad.hg38.vcf.gz.tbi
# -rwxr-xr-x 1 root root 1.7K Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root 295K Apr 28 13:35 california_housing_test.csv
# -rw-r--r-- 1 root root 1.7M Apr 28 13:35 california_housing_train.csv
# -rw-r--r-- 1 root root    0 Apr 30 14:19 file_list
# -rw-r--r-- 1 root root  18M Apr 28 13:35 mnist_test.csv
# -rw-r--r-- 1 root root  35M Apr 28 13:35 mnist_train_small.csv
# -rw-r--r-- 1 root root    0 Apr 30 13:52 new3
# drwxr-xr-x 2 root root 4.0K Apr 30 13:55 newdir2
# -rw-r--r-- 1 root root  114 Apr 30 14:05 new.tar.gz
# -rwxr-xr-x 1 root root  962 Jan  1  2000 README.md
# -rw-r--r-- 1 root root 2.0K Apr 30 14:12 result
# -rw-r--r-- 1 root root 295K Apr 30 14:14 tmp

# %%
# !for i in $(cat file_list); do echo $i; done

# %% [markdown]
# # 3.3 运行脚本

# %% [markdown]
# (1) 写一个脚本
# (2) 更改权限为 +x
# (3) 运行

# %% [markdown]
# # 3.4 vi

# %% [markdown]
# # 3.5 后台运行脚本

# %%
# !nohup XXXXXXXXXX &
